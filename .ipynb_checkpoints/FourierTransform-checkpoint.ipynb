# %% [markdown]
# <a href="https://colab.research.google.com/github/abdelrahim-hentabli/CS235Project/blob/main/FourierTransform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# import the scatter_matrix functionality
import random as rand
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from scipy.fftpack import fft

# %% [markdown]
# # 1. Data Analysis

# %%
apple = pd.read_csv('./Data/Stocks/aapl.us.txt')
print(apple)
# Out:
#             Date       Open       High        Low      Close    Volume  \
# 0     1984-09-07    0.42388    0.42902    0.41874    0.42388  23220030
# 1     1984-09-10    0.42388    0.42516    0.41366    0.42134  18022532
# 2     1984-09-11    0.42516    0.43668    0.42516    0.42902  42498199
# 3     1984-09-12    0.42902    0.43157    0.41618    0.41618  37125801
# 4     1984-09-13    0.43927    0.44052    0.43927    0.43927  57822062
# ...          ...        ...        ...        ...        ...       ...
# 8359  2017-11-06  171.75000  174.36000  171.10000  173.63000  34901241
# 8360  2017-11-07  173.29000  174.51000  173.29000  174.18000  24424877
# 8361  2017-11-08  174.03000  175.61000  173.71000  175.61000  24451166
# 8362  2017-11-09  174.48000  175.46000  172.52000  175.25000  29533086
# 8363  2017-11-10  175.11000  175.38000  174.27000  174.67000  25130494
#
#       OpenInt
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# ...

# %% [markdown]
# ## Clean Up
# Adding Return percentage per day for apple stock prices

# %%
percent = (apple.Open - apple.Close) / (apple.Open) * 100
apple['Return'] = percent
print(apple)
# Out:
#             Date       Open       High        Low      Close    Volume  \
# 0     1984-09-07    0.42388    0.42902    0.41874    0.42388  23220030
# 1     1984-09-10    0.42388    0.42516    0.41366    0.42134  18022532
# 2     1984-09-11    0.42516    0.43668    0.42516    0.42902  42498199
# 3     1984-09-12    0.42902    0.43157    0.41618    0.41618  37125801
# 4     1984-09-13    0.43927    0.44052    0.43927    0.43927  57822062
# ...          ...        ...        ...        ...        ...       ...
# 8359  2017-11-06  171.75000  174.36000  171.10000  173.63000  34901241
# 8360  2017-11-07  173.29000  174.51000  173.29000  174.18000  24424877
# 8361  2017-11-08  174.03000  175.61000  173.71000  175.61000  24451166
# 8362  2017-11-09  174.48000  175.46000  172.52000  175.25000  29533086
# 8363  2017-11-10  175.11000  175.38000  174.27000  174.67000  25130494
#
#       OpenInt    Return
# 0           0  0.000000
# 1           0  0.599226
# 2           0 -0.907893
# ...

# %% [raw]
# One of the best ways to inspect data is visualize it. One way to do this is by using a scatter plot. A scatter plot of the data puts one feature along the x-axis and another along the y-axis, and draws a dot for each data point.
#
# Since its difficult to visualize more than 2 or 3 features, one possibility is to use a pair plot that looks at all possible pairs of features. The pair plot shows the interaction of each pair of features inorder to visualize any correlation between features.

# %%
x = apple.iloc[:,[1,2,3,4,5]] # extract only a subset of columns from dataframe (using index)
y = x.dropna(thresh=5) # drop any rows that have 5 or more fields as NAN  
a = pd.plotting.scatter_matrix(x, alpha=0.05, figsize=(8,7), diagonal='hist')
plt.show()

# %% [markdown]
# # 2. Pre-Processing
#
# ## Fourier Analysis
# Analyzing data for Fourier Transform, looking at Apple stock closing price per day over time and daily return percentage over time.

# %%
figure, axes = plt.subplots(2, 2,figsize=(20,10))


apple.plot.line('Date', 'Close', title="Closing vs Time", ylabel ='Amount',ax=axes[1,0])

# plt.subplot(2,2,2)
# assigning time values of the signal
signalAmplitude = np.sin(apple.Close)
# plotting the magnitude spectrum of the signal 
pd1 = plt.magnitude_spectrum(signalAmplitude,Fs=100, color='red')

apple.plot.line('Date','Return', title="Return vs Time", ylabel='Return %',ax=axes[0,0])

plt.subplot(2,2,2)
signalAmplitude = np.sin(apple.Return)
plt.magnitude_spectrum(signalAmplitude,Fs=100,pad_to=100, color='red')
# Out:
# (array([1.92233768e-06, 1.02065803e-06, 6.64401556e-07, 7.77525944e-07,
#         7.01209454e-07, 2.89271884e-07, 1.27437350e-07, 4.63000883e-07,
#         9.89281330e-07, 8.33612915e-07, 6.16752716e-07, 7.76059711e-07,
#         7.35454681e-07, 8.60462629e-07, 6.12093061e-07, 3.84089475e-07,
#         8.96234571e-07, 1.42134098e-06, 1.12038773e-06, 1.24573340e-06,
#         1.04675286e-06, 7.68414061e-07, 6.31064416e-07, 1.51996423e-06,
#         1.51525507e-06, 1.25487498e-06, 5.07956611e-07, 9.18940366e-07,
#         1.07359246e-06, 7.93045827e-07, 3.27280033e-07, 4.88670751e-07,
#         9.64244964e-07, 9.16367278e-07, 7.39145118e-07, 9.25578621e-07,
#         8.33052215e-07, 5.38463416e-07, 4.23404797e-07, 1.48401289e-06,
#         1.09035269e-06, 9.43759581e-07, 9.37207082e-07, 7.48625501e-07,
#         6.76769229e-07, 7.26842194e-07, 6.01591302e-07, 6.12999881e-07,
#         1.21817217e-06, 9.02283001e-07, 7.74402174e-07]),
# ...

# %% [markdown]
# A financial time series is not stationary, therefore, Fourier transformation would not be applicable for this data series. We are able to see this throught the frequency graphs that show how the behavior of the frequency magnitude is either chaotic or non-existent.

# %%
from scipy import fftpack

sig = np.sin(2*np.pi*apple.Return[-100:]/5).to_numpy()

sig_fft  = fftpack.fft(sig)

# plt.plot(sig_fft) 
amplitude = np.abs(sig_fft)
power = amplitude**2
angle = np.angle(sig_fft)

sample_freq = fftpack.fftfreq(sig.size)

amp_freq = np.array([amplitude, sample_freq])

amp_position = amp_freq[0,:].argmax()
peak_freq =  amp_freq[1, amp_position]

# print(amp_position)
# print(peak_freq)

#remove noise
high_freq_ftt = sig_fft.copy()
high_freq_ftt[np.abs(sample_freq) > peak_freq] = 0
# print(high_freq_ftt)

filter_sig  = fftpack.ifft(high_freq_ftt)

plt.plot(sig)
plt.plot(filter_sig)
plt.legend(['signal','filtered signal'],loc="lower left")
# Out:
# /Users/samtapia/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
import numpy as np
import pylab as pl
from numpy import fft

def fftPrediction(x, n_predict):
    n = x.size
    n_harm = 10                     # number of harmonics in model
    t = np.arange(0, n)
    p = np.polyfit(t, x, 1)         # find linear trend in x
    x_notrend = x - p[0] * t        # detrended x
    x_freqdom = fft.fft(x)  # detrended x in frequency domain
    f = fft.fftfreq(n)              # frequencies
    indexes = list(range(n))
    # sort indexes by frequency, lower -> higher
    indexes.sort(key = lambda i: np.absolute(x_freqdom[i]))
    indexes.reverse()
#     indexes.sort(key = lambda i: np.absolute(f[i]))
 
    t = np.arange(0, n + n_predict)
    restored_sig = np.zeros(t.size)
    for i in indexes[:1 + n_harm * 2]:
        ampli = np.absolute(x_freqdom[i]) / n   # amplitude
        phase = np.angle(x_freqdom[i])          # phase
        restored_sig += ampli * np.cos(2 * np.pi * f[i] * t + phase)
    return restored_sig + p[0] * t

# %%
x = apple.Close[-365:].to_numpy()
n_predict = 100
extrapolation = fftPrediction(x, n_predict)
pl.plot(np.arange(0, extrapolation.size), extrapolation, 'r', label = 'Prediction')
pl.plot(np.arange(0, x.size), x, 'b', label = 'Closing', linewidth = 3)
pl.legend()
pl.show()

# %%
#data function
y = apple.Close[-365:].to_numpy()
y1 = apple.Return[-365:].to_numpy()
# print(y)

#fast fourier transform
y_fft = fftpack.fft(y)
fft_abs = abs(y_fft)

y_fft1 = fftpack.fft(y1)
fft_abs1 = abs(y_fft1)

#plot data
t = np.arange(0,y.size)
t1 = np.arange(0,y1.size)
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15,5))
ax[0][0].plot(t, y)    # plot time series
ax[0][1].plot(t, fft_abs, color='red') # plot freq domain
ax[1][0].plot(t1, y1)    # plot time series
ax[1][1].plot(t1, fft_abs1, color='red') # plot freq domain
